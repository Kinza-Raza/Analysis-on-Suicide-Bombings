# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv("suicide_bombings.csv")
file.head()
# Out:
#    Unnamed: 0  Date        Day     Month  Year               Islamic Date  \
# 0           0    19     Sunday  November  1995  26 Jumada al-Akhirah 1416
# 1           1     6     Monday  November  2000            10 Sha’ban 1421
# 2           2     8  Wednesday       May  2002              25 Safar 1423
# 3           3    14     Friday      June  2002     03 Rabi’ al-Thani 1423
# 4           4     4     Friday      July  2003      04 Jumada al-Ula 1424
#
#   Blast Day Type Holiday Type      Time       City  ...  Killed Min Killed   \
# 0        Holiday      Weekend       NaN  Islamabad  ...        14.0    15.0
# 1    Working Day          NaN       NaN    Karachi  ...         NaN     3.0
# 2    Working Day          NaN  07:45:00    Karachi  ...        13.0    15.0
# 3    Working Day          NaN  11:10:00    Karachi  ...         NaN    12.0
# 4    Working Day          NaN       NaN     Quetta  ...        44.0    47.0
#
# ...

# %%
print(file[file["City"] == "Hayatabad"]["Longitude"])
# Out:
# 473     71.456944
# Name: Longitude, dtype: object
